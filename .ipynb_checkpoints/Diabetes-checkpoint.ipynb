# %% [markdown]
# Diabetes Prediction

# %% [raw]
# Diabetes is a common chronic disease that can lead to serious health complications if it is not identified early. The objective of this project is to develop a machine learning-based diabetes prediction system that analyzes patient demographic, lifestyle, medical, and clinical information to predict whether a patient is likely to be diagnosed with diabetes. A Random Forest Classifier is used to learn patterns from the available patient data and provide a binary prediction of diabetes or non-diabetes. The system can help demonstrate how machine learning can support early risk identification and data-driven healthcare decision-making.

# %% [raw]
# This dataset contains 100,000 patient records with 31 columns.
# It includes demographic information such as age, gender, and ethnicity.
# Lifestyle factors include alcohol consumption, physical activity, diet, sleep, and screen time.
# Medical history includes family history of diabetes, hypertension, and cardiovascular history.
# Body measurements include BMI and waist-to-hip ratio.
# Cardiovascular features include blood pressure, heart rate, and cholesterol levels.
# Glucose-related features include fasting glucose, postprandial glucose, insulin, and HbA1c.
# diabetes_risk_score provides an additional measure of diabetes risk.
# diagnosed_diabetes is the target variable used to predict whether a patient has diabetes.
# These features are used by the Random Forest model to classify patients into diabetes and non-diabetes classes.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("diabetes_dataset.csv")

# %%
ds=df.copy()

# %%
df
# Out:
#        age  gender ethnicity education_level  income_level employment_status  \
# 0       58    Male     Asian      Highschool  Lower-Middle          Employed
# 1       48  Female     White      Highschool        Middle          Employed
# 2       60    Male  Hispanic      Highschool        Middle        Unemployed
# 3       74  Female     Black      Highschool           Low           Retired
# 4       46    Male     White        Graduate        Middle           Retired
# ...    ...     ...       ...             ...           ...               ...
# 99995   46    Male     Other        Graduate  Upper-Middle        Unemployed
# 99996   41  Female     White        Graduate        Middle          Employed
# 99997   57  Female     Black       No formal  Upper-Middle          Employed
# 99998   47  Female     Black      Highschool  Lower-Middle           Retired
# 99999   52  Female     White    Postgraduate        Middle          Employed
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   age                                 100000 non-null  int64
#  1   gender                              100000 non-null  object
#  2   ethnicity                           100000 non-null  object
#  3   education_level                     100000 non-null  object
#  4   income_level                        100000 non-null  object
#  5   employment_status                   100000 non-null  object
#  6   smoking_status                      100000 non-null  object
#  7   alcohol_consumption_per_week        100000 non-null  int64
#  8   physical_activity_minutes_per_week  100000 non-null  int64
#  9   diet_score                          100000 non-null  float64
#  10  sleep_hours_per_day                 100000 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 age  alcohol_consumption_per_week  \
# count  100000.00000                 100000.000000
# mean       50.12041                      2.003670
# std        15.60460                      1.417779
# min        18.00000                      0.000000
# 25%        39.00000                      1.000000
# 50%        50.00000                      2.000000
# 75%        61.00000                      3.000000
# max        90.00000                     10.000000
#
#        physical_activity_minutes_per_week     diet_score  sleep_hours_per_day  \
# count                       100000.000000  100000.000000        100000.000000
# mean                           118.911640       5.994787             6.997818
# std                             84.409662       1.780954             1.094622
# min                              0.000000       0.000000             3.000000
# 25%                             57.000000       4.800000             6.300000
# ...

# %%
df["diagnosed_diabetes"].value_counts()
# Out:
# diagnosed_diabetes
# 1    59998
# 0    40002
# Name: count, dtype: int64

# %%
def find_outliers(df, columns):
    """
    Find outliers using the IQR method.

    Parameters:
        df (pd.DataFrame): Input DataFrame
        columns (list): List of numerical columns

    Returns:
        dict: Dictionary containing outlier DataFrames for each column
    """
    outliers = {}

    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outlier_rows = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

        outliers[col] = outlier_rows

        print(f"\nColumn: {col}")
        print(f"Lower Bound : {lower_bound:.2f}")
        print(f"Upper Bound : {upper_bound:.2f}")
        print(f"Number of Outliers : {len(outlier_rows)}")

    return outliers

# %%
find_outliers(df, ["family_history_diabetes"])
# Out:
# Column: family_history_diabetes
# Lower Bound : 0.00
# Upper Bound : 0.00
# Number of Outliers : 21941
# {'family_history_diabetes':        age  gender ethnicity education_level  income_level employment_status  \
#  2       60    Male  Hispanic      Highschool        Middle        Unemployed
#  23      27  Female  Hispanic      Highschool           Low          Employed
#  26      32  Female     White      Highschool        Middle           Retired
#  29      45  Female     Black        Graduate  Lower-Middle           Retired
#  34      63    Male     White      Highschool           Low          Employed
#  ...    ...     ...       ...             ...           ...               ...
#  99960   72    Male     White      Highschool  Upper-Middle           Retired
#  99961   57    Male     Black      Highschool  Upper-Middle          Employed
#  99967   44  Female     White       No formal        Middle          Employed
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df["family_history_diabetes"])
plt.show()

# %%
sns.displot(data=df,x="diagnosed_diabetes",kde=True)

# %%
## Univariate Analysis
# !pip install sweetviz 
#installing sweetviz library`

# %%
import sweetviz as sv                       #importing sweetviz library 
my_report = sv.analyze(df)                #syntax to use sweetviz
my_report.show_html()                       #Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df["gender"]
# Out:
# 0          Male
# 1        Female
# 2          Male
# 3        Female
# 4          Male
#           ...
# 99995      Male
# 99996    Female
# 99997    Female
# 99998    Female
# 99999    Female
# Name: gender, Length: 100000, dtype: object

# %%
df.gender=le.fit_transform(df.gender)

# %%
df['ethnicity'].value_counts()
# Out:
# ethnicity
# White       44997
# Hispanic    20103
# Black       17986
# Asian       11865
# Other        5049
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df, columns=['ethnicity'], drop_first=True, dtype=int)

# %%
df
# Out:
#        age  gender education_level  income_level employment_status  \
# 0       58       1      Highschool  Lower-Middle          Employed
# 1       48       0      Highschool        Middle          Employed
# 2       60       1      Highschool        Middle        Unemployed
# 3       74       0      Highschool           Low           Retired
# 4       46       1        Graduate        Middle           Retired
# ...    ...     ...             ...           ...               ...
# 99995   46       1        Graduate  Upper-Middle        Unemployed
# 99996   41       0        Graduate        Middle          Employed
# 99997   57       0       No formal  Upper-Middle          Employed
# 99998   47       0      Highschool  Lower-Middle           Retired
# 99999   52       0    Postgraduate        Middle          Employed
#
#       smoking_status  alcohol_consumption_per_week  \
# 0              Never                             0
# 1             Former                             1
# ...

# %%
df["education_level"].value_counts()
# Out:
# education_level
# Highschool      44891
# Graduate        35037
# Postgraduate    14972
# No formal        5100
# Name: count, dtype: int64

# %%
df.education_level=df.education_level.map({"Highschool":1,"Graduate":2,"Postgraduate":3,"No formal":4})

# %%
df["smoking_status"]
# Out:
# 0         Never
# 1        Former
# 2         Never
# 3         Never
# 4         Never
#           ...
# 99995    Former
# 99996     Never
# 99997    Former
# 99998     Never
# 99999     Never
# Name: smoking_status, Length: 100000, dtype: object

# %%
df.smoking_status=le.fit_transform(df.smoking_status)

# %%
df.diabetes_stage.value_counts()
# Out:
# diabetes_stage
# Type 2          59774
# Pre-Diabetes    31845
# No Diabetes      7981
# Gestational       278
# Type 1            122
# Name: count, dtype: int64

# %%
df=pd.get_dummies(df,columns=["diabetes_stage"], drop_first=True, dtype=int)

# %%
df["income_level"].value_counts()
# Out:
# income_level
# Middle          35152
# Lower-Middle    25150
# Upper-Middle    19866
# Low             14830
# High             5002
# Name: count, dtype: int64

# %%
df.income_level=df.income_level.map({"Middle":1,"Lower-Middle":2,"Upper-Middle":3,"Low":4,"High":5})

# %%
df["employment_status"].value_counts()
# Out:
# employment_status
# Employed      60175
# Retired       21761
# Unemployed    11918
# Student        6146
# Name: count, dtype: int64

# %%
df=pd.get_dummies(df,columns=["employment_status"], drop_first=True, dtype=int)

# %%
df
# Out:
#        age  gender  education_level  income_level  smoking_status  \
# 0       58       1                1             2               2
# 1       48       0                1             1               1
# 2       60       1                1             1               2
# 3       74       0                1             4               2
# 4       46       1                2             1               2
# ...    ...     ...              ...           ...             ...
# 99995   46       1                2             3               1
# 99996   41       0                2             1               2
# 99997   57       0                4             3               1
# 99998   47       0                1             2               2
# 99999   52       0                3             1               2
#
#        alcohol_consumption_per_week  physical_activity_minutes_per_week  \
# 0                                 0                                 215
# ...

# %%
x=df.drop("diagnosed_diabetes",axis=1)
y=df["diagnosed_diabetes"]

# %%
x
# Out:
#        age  gender  education_level  income_level  smoking_status  \
# 0       58       1                1             2               2
# 1       48       0                1             1               1
# 2       60       1                1             1               2
# 3       74       0                1             4               2
# 4       46       1                2             1               2
# ...    ...     ...              ...           ...             ...
# 99995   46       1                2             3               1
# 99996   41       0                2             1               2
# 99997   57       0                4             3               1
# 99998   47       0                1             2               2
# 99999   52       0                3             1               2
#
#        alcohol_consumption_per_week  physical_activity_minutes_per_week  \
# 0                                 0                                 215
# ...

# %%
y
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diagnosed_diabetes, Length: 100000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
base_pred = model.predict(x_test)

# %%
#evalution
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
confusion_matrix(y_test,base_pred)
# Out:
# array([[12053,    14],
#        [   11, 17922]])

# %%
print(classification_report(y_test,base_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     12067
#            1       1.00      1.00      1.00     17933
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000

# %%
from sklearn.ensemble import RandomForestClassifier

Model = RandomForestClassifier(
    random_state=42
)

Model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
pred=Model.predict(x_test)

# %%
confusion_matrix(y_test,base_pred)
# Out:
# array([[12053,    14],
#        [   11, 17922]])

# %%
print(classification_report(y_test,base_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     12067
#            1       1.00      1.00      1.00     17933
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000

# %%
import joblib

joblib.dump(Model, "random_forest_model.pkl")
# Out:
# ['random_forest_model.pkl']
